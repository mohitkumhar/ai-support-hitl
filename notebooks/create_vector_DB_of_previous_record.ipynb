# %%
from langchain_chroma import Chroma

# %%
import os
from dotenv import load_dotenv

from langchain_openai import OpenAIEmbeddings

from langchain_community.document_loaders import JSONLoader

# %%
load_dotenv()
# Out:
# True

# %%
OPEN_AI_KEY = os.getenv("OPEN_AI_KEY")

# %%
embeddings = OpenAIEmbeddings(
    api_key=OPEN_AI_KEY,
    model="text-embedding-3-large",
    base_url="https://openrouter.ai/api/v1",
)

# %%
vector_db = Chroma(
    collection_name="PreviousData",
    embedding_function=embeddings,
    persist_directory="Company_Info_VectorDB",
)

# %%
vector_db.get()
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}

# %%
# loading previous_record text data

# %%
def metadata_func(record: dict, metadata: dict) -> dict:
    # Extract top-level fields
    metadata["ticket_id"] = record.get("ticket_id")
    metadata["resolution"] = record.get("resolution")
    metadata["creation_time"] = record.get("ticket_creation_time")
    metadata["closure_time"] = record.get("ticket_closure_time")
    
    # Extract nested metadata fields (category and priority)
    # Using .get() with an empty dict {} prevents errors if metadata is missing
    inner_meta = record.get("metadata", {})
    metadata["category"] = inner_meta.get("category")
    metadata["priority"] = inner_meta.get("priority")
    
    return metadata

# %%
loader = JSONLoader(
    file_path="previous_record.json",
    jq_schema=".[]",
    content_key="issue",
    metadata_func=metadata_func
)

# %%
docs = loader.load()

# %%
for doc in docs:
    print(doc)
    break
# Out:
# page_content='Payment deducted but order was not placed' metadata={'source': 'C:\\Users\\write\\Desktop\\ai_chatbot_with_memory_and_tools\\previous_record.json', 'seq_num': 1, 'ticket_id': 'TKT_000001', 'resolution': 'Payment verified and refund initiated to original payment method within 3–5 business days', 'creation_time': '2024-10-12T09:14:22', 'closure_time': '2024-10-12T13:45:10', 'category': 'payment', 'priority': 'high'}

# %%
for doc in docs:
    doc.metadata["source"] = "previous_record.json"

# %%
for doc in docs:
    print(doc)
    print()
# Out:
# page_content='Payment deducted but order was not placed' metadata={'source': 'previous_record.json', 'seq_num': 1, 'ticket_id': 'TKT_000001', 'resolution': 'Payment verified and refund initiated to original payment method within 3–5 business days', 'creation_time': '2024-10-12T09:14:22', 'closure_time': '2024-10-12T13:45:10', 'category': 'payment', 'priority': 'high'}
#
# page_content='Order marked delivered but customer did not receive it' metadata={'source': 'previous_record.json', 'seq_num': 2, 'ticket_id': 'TKT_000002', 'resolution': 'Delivery investigation opened and replacement order created', 'creation_time': '2024-10-10T16:05:44', 'closure_time': '2024-10-11T11:20:30', 'category': 'delivery', 'priority': 'high'}
#
# page_content='Refund not received even after 7 days' metadata={'source': 'previous_record.json', 'seq_num': 3, 'ticket_id': 'TKT_000003', 'resolution': 'Refund delay escalated to finance team and customer informed', 'creation_time': '2024-10-08T10:01:12', 'closure_time': '2024-10-09T14:40:55', 'category': 'refund', 'priority': 'medium'}
#
# page_content='Wrong item delivered instead of ordered product' metadata={'source': 'previous_record.json', 'seq_num': 4, 'ticket_id': 'TKT_000004', 'resolution': 'Replacement order created and return pickup scheduled', 'creation_time': '2024-10-09T12:33:18', 'closure_time': '2024-10-09T18:10:41', 'category': 'order', 'priority': 'medium'}
#
# page_content='Account locked due to multiple failed login attempts' metadata={'source': 'previous_record.json', 'seq_num': 5, 'ticket_id': 'TKT_000005', 'resolution': 'Account unlocked after identity verification and password reset link sent', 'creation_time': '2024-10-11T08:20:09', 'closure_time': '2024-10-11T09:45:02', 'category': 'account', 'priority': 'high'}
#
# page_content='Customer received an item with missing accessories' metadata={'source': 'previous_record.json', 'seq_num': 6, 'ticket_id': 'TKT_000006', 'resolution': 'Missing accessories shipped separately at no additional cost', 'creation_time': '2024-10-13T11:18:45', 'closure_time': '2024-10-13T17:02:10', 'category': 'product', 'priority': 'medium'}
#
# page_content='Order automatically cancelled due to address verification failure' metadata={'source': 'previous_record.json', 'seq_num': 7, 'ticket_id': 'TKT_000007', 'resolution': 'Customer address confirmed and order successfully re-created', 'creation_time': '2024-10-14T09:42:30', 'closure_time': '2024-10-14T12:55:20', 'category': 'order', 'priority': 'medium'}
#
# page_content='Customer charged delivery fee despite being eligible for free shipping' metadata={'source': 'previous_record.json', 'seq_num': 8, 'ticket_id': 'TKT_000008', 'resolution': 'Delivery charges refunded after eligibility verification', 'creation_time': '2024-10-15T14:06:11', 'closure_time': '2024-10-15T18:40:52', 'category': 'payment', 'priority': 'medium'}
#
# page_content='Return pickup not attempted on scheduled date' metadata={'source': 'previous_record.json', 'seq_num': 9, 'ticket_id': 'TKT_000009', 'resolution': 'Return pickup rescheduled and customer notified', 'creation_time': '2024-10-16T10:22:55', 'closure_time': '2024-10-16T15:10:33', 'category': 'refund', 'priority': 'medium'}
#
# page_content='Customer reported incorrect invoice amount' metadata={'source': 'previous_record.json', 'seq_num': 10, 'ticket_id': 'TKT_000010', 'resolution': 'Invoice corrected and updated invoice shared with customer', 'creation_time': '2024-10-17T13:47:08', 'closure_time': '2024-10-17T16:58:41', 'category': 'payment', 'priority': 'low'}
#
# page_content='Product delivered later than promised delivery date' metadata={'source': 'previous_record.json', 'seq_num': 11, 'ticket_id': 'TKT_000011', 'resolution': 'Delivery delay acknowledged and compensation credit issued', 'creation_time': '2024-10-18T08:35:19', 'closure_time': '2024-10-18T14:12:05', 'category': 'delivery', 'priority': 'medium'}
#
# page_content='Customer unable to apply promotional coupon during checkout' metadata={'source': 'previous_record.json', 'seq_num': 12, 'ticket_id': 'TKT_000012', 'resolution': 'Coupon conditions explained and manual discount applied', 'creation_time': '2024-10-19T16:09:27', 'closure_time': '2024-10-19T19:45:54', 'category': 'order', 'priority': 'low'}
#
# page_content='Order returned but refund not initiated' metadata={'source': 'previous_record.json', 'seq_num': 13, 'ticket_id': 'TKT_000013', 'resolution': 'Return receipt confirmed and refund initiated', 'creation_time': '2024-10-20T09:51:40', 'closure_time': '2024-10-20T18:22:16', 'category': 'refund', 'priority': 'medium'}
#
# page_content='Customer account flagged for suspicious activity' metadata={'source': 'previous_record.json', 'seq_num': 14, 'ticket_id': 'TKT_000014', 'resolution': 'Account secured after verification and access restored', 'creation_time': '2024-10-21T07:58:03', 'closure_time': '2024-10-21T10:36:49', 'category': 'account', 'priority': 'high'}
#
# page_content='Customer received refurbished item instead of new' metadata={'source': 'previous_record.json', 'seq_num': 15, 'ticket_id': 'TKT_000015', 'resolution': 'Replacement with new item approved and return arranged', 'creation_time': '2024-10-22T15:14:26', 'closure_time': '2024-10-22T20:05:10', 'category': 'product', 'priority': 'high'}

# %%
f"loaded {len(docs)} documents"
# Out:
# 'loaded 15 documents'

# %%
vector_db.add_documents(docs)
# Out:
# ['491cd061-26a0-4072-9012-81a0d748e22d',
#  '1e05a3b8-ffba-459e-902c-9538e6cab4b6',
#  '441f39a0-2058-4231-ac4f-65692d5ec938',
#  '8e3fc13d-5936-44e4-90e9-347b2d9c8095',
#  '6800373d-e5df-4463-bb81-dc408aee7838',
#  'bca2b128-f637-4d1e-a218-f1b42559c900',
#  '60cb9ba5-aef8-4007-96fa-18723ea1f23c',
#  '2a7e6db2-8465-4663-9c86-a63508a2d029',
#  '031a8e63-9943-4566-b619-267a1d3090b4',
#  'd8159a23-be41-4c17-a81f-ad5b84c77549',
#  'e6532c09-89f2-47f1-904d-7cb125e705ff',
#  '46b2534f-1725-4eba-8d5a-940a4fccf02b',
#  '39f45f5c-a91b-4fba-af3f-fbbe2708f7fc',
#  '7eb430ad-96fe-4160-9a9f-d4ff5ccfe9f0',
#  '029f02df-6bb0-48c0-ae21-efa5d54c037c']

# %%
vector_db.get(include=["documents", "embeddings"])
# Out:
# {'ids': ['491cd061-26a0-4072-9012-81a0d748e22d',
#   '1e05a3b8-ffba-459e-902c-9538e6cab4b6',
#   '441f39a0-2058-4231-ac4f-65692d5ec938',
#   '8e3fc13d-5936-44e4-90e9-347b2d9c8095',
#   '6800373d-e5df-4463-bb81-dc408aee7838',
#   'bca2b128-f637-4d1e-a218-f1b42559c900',
#   '60cb9ba5-aef8-4007-96fa-18723ea1f23c',
#   '2a7e6db2-8465-4663-9c86-a63508a2d029',
#   '031a8e63-9943-4566-b619-267a1d3090b4',
#   'd8159a23-be41-4c17-a81f-ad5b84c77549',
#   'e6532c09-89f2-47f1-904d-7cb125e705ff',
#   '46b2534f-1725-4eba-8d5a-940a4fccf02b',
#   '39f45f5c-a91b-4fba-af3f-fbbe2708f7fc',
#   '7eb430ad-96fe-4160-9a9f-d4ff5ccfe9f0',
#   '029f02df-6bb0-48c0-ae21-efa5d54c037c'],
#  'embeddings': array([[-0.00730934,  0.03768184,  0.0043503 , ..., -0.01745658,
#           0.00709476,  0.00777309],
#         [ 0.02410882,  0.03894284,  0.00079462, ...,  0.01491911,
#          -0.01046607,  0.00272997],
#         [-0.00241064,  0.0204614 , -0.00120371, ..., -0.00164318,
#           0.02144375,  0.00206165],
#         ...,
#         [-0.00616167,  0.04075532,  0.00077405, ...,  0.00617703,
#           0.02298821,  0.00426902],
#         [-0.03602384, -0.01437571,  0.00993615, ...,  0.00228532,
#           0.03135596, -0.00711175],
#         [-0.02219188,  0.00227729,  0.00945342, ..., -0.01061538,
#          -0.00725862, -0.00644454]], shape=(15, 3072)),
#  'documents': ['Payment deducted but order was not placed',
#   'Order marked delivered but customer did not receive it',
#   'Refund not received even after 7 days',
#   'Wrong item delivered instead of ordered product',
#   'Account locked due to multiple failed login attempts',
#   'Customer received an item with missing accessories',
#   'Order automatically cancelled due to address verification failure',
#   'Customer charged delivery fee despite being eligible for free shipping',
#   'Return pickup not attempted on scheduled date',
#   'Customer reported incorrect invoice amount',
#   'Product delivered later than promised delivery date',
#   'Customer unable to apply promotional coupon during checkout',
#   'Order returned but refund not initiated',
#   'Customer account flagged for suspicious activity',
#   'Customer received refurbished item instead of new'],
#  'uris': None,
#  'included': ['documents', 'embeddings'],
#  'data': None,
#  'metadatas': None}
